# %%
import os
import pypdf  


def read_resume():
    """Read resume from data folder (supports PDF and TXT)"""
  
    
    # Try PDF first
    pdf_path = "D:\\Github\\Job_Finding_AI_Agent\\data\\CV.pdf"
    if os.path.exists(pdf_path):
        try:
            with open(pdf_path, 'rb') as f:
                reader = pypdf.PdfReader(f)
                text = ""
                for page in reader.pages:
                    text += page.extract_text()
                return text
        except Exception as e:
            return f"Error reading PDF: {str(e)}"
    
    # Try TXT as fallback
    txt_path = "data/resume.txt"
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as f:
            return f.read()
    
    return "Resume not found. Please add data/resume.pdf or data/resume.txt"

print(read_resume())

# %%
from llm import ask_llama
import textwrap
from tools import read_resume
from tools import search_jobs
from tools import save_application




def test_basic_functions():
    """Test basic functionality"""
    print("=== Testing Basic Functions ===\n")
    
    # Test 1: LLM connection
    print("1. Testing LLM...")
    response = ask_llama("Say 'Hello' if you can read this.")
    wrapped = textwrap.fill(response, width=80)  # Wrap at 80 characters
    print(f"LLM Response:\n{wrapped}\n")
    
    # Test 2: Read resume
    print("2. Testing read_resume...")
    resume = read_resume()
    print(f"Resume (first 100 chars): {resume[:100]}...\n, type: {type(resume)}\n")
    
    # Test 3: Search jobs
    print("3. Testing search_jobs...")
    jobs = search_jobs("python", "Seattle")
    print(f"Jobs found: {jobs}...\n")
    
    # Test 4: Save application
    print("4. Testing save_application...")
    result = save_application("Test Job", "Test Company", "This is a test cover letter")
    print(f"Save result: {result}\n")
    
    print("=== Tests Complete ===")

test_basic_functions()
# Out:
# === Testing Basic Functions ===
#
# 1. Testing LLM...
# LLM Response: I think I can! However, I'm a large language model, I don't have the ability to "read" in the classical sense, but I've been trained on vast amounts of text data and can understand human-like input.
#
# So, yes, I can "read" your message and respond accordingly. Hello back to you!
#
# 2. Testing read_resume...
# Resume (first 100 chars): Tingyu Zhang
# /envel⌢petingyu.z@northeastern.edu.♂phone206-741-8937./linkedinLinkedIn./githubGitHub. ...
# , type: <class 'str'>
#
# 3. Testing search_jobs...
# Jobs found: [
#   {
#     "title": "Software Engineer",
#     "company": "TechCorp",
#     "location": "Seattle",
#     "description": "Looking for Python developer with AI experience",
#     "url": "https://example.com/job1"
#   },
#   {
#     "title": "Backend Developer",
#     "company": "StartupXYZ",
#     "location": "Seattle",
#     "description": "Node.js and database experience required",
#     "url": "https://example.com/job2"
#   }
# ]...
#
# 4. Testing save_application...
# Save result: Application saved to data-applications-Test_Company_Test_Job_20260201.txt
#
# === Tests Complete ===

# %%
# Out:
# vectorizer: TfidfVectorizer()
# Shape: (3, 5)
# Type: <class 'scipy.sparse._csr.csr_matrix'>
#
# As array:
# [[0.         0.         0.68091856 0.51785612 0.51785612]
#  [0.68091856 0.51785612 0.         0.51785612 0.        ]
#  [0.         0.70710678 0.         0.         0.70710678]]
#
# Words: ['fast' 'fastapi' 'great' 'is' 'python']

# %%
# Out:
# This demo shows how RAG improves LLM responses by providing context.
# Press Ctrl+C to exit anytime.
#
#
# Available knowledge base:
#   1. Python 3.12 was released in October 2023 with improved error messages.
#   2. FastAPI is a modern web framework for building APIs with Python.
#   3. Django is a full-stack web framework that includes ORM and admin panel.
#   4. RAG stands for Retrieval-Augmented Generation, combining search with LLMs.
#   5. Machine learning models require training data and validation sets.
#   6. REST APIs use HTTP methods like GET, POST, PUT, and DELETE.
#
# ======================================================================
# 🔴 WITHOUT RAG - Direct LLM Query
# ======================================================================
# Question: What is FastAPI?
#
# Prompt sent to Llama:
# Answer this question briefly: What is FastAPI?
#
# ----------------------------------------------------------------------
# Llama's Response:
# FastAPI is a modern, fast (high-performance), web framework for building APIs with Python 3.7+ based on standard Python type hints. It allows for automatic API documentation and supports asynchronous coding.
#
# ======================================================================
# 🟢 WITH RAG - Retrieve Context + LLM Query
# ======================================================================
# Question: What is FastAPI?
#
# Retrieved Context from Knowledge Base:
#   1. FastAPI is a modern web framework for building APIs with Python.
#   2. Django is a full-stack web framework that includes ORM and admin panel.
#
# Enhanced Prompt sent to Llama:
# Use the following context to answer the question:
#
# Context:
# FastAPI is a modern web framework for building APIs with Python.
# Django is a full-stack web framework that includes ORM and admin panel.
#
# Question: What is FastAPI?
#
# Answer based on the context above:
#
# ----------------------------------------------------------------------
# Llama's Response:
# Based on the given context, FastAPI is a modern web framework used to build APIs with Python.
#
# ======================================================================
# COMPARISON:
# ======================================================================
# Without RAG: FastAPI is a modern, fast (high-performance), web framework for building APIs with Python 3.7+ based on standard Python type hints. It allows for automatic API documentation and supports asynchronous coding.
# With RAG: Based on the given context, FastAPI is a modern web framework used to build APIs with Python.
# Result: More accurate, specific, and grounded responses!
#
# ======================================================================
# 🔴 WITHOUT RAG - Direct LLM Query
# ======================================================================
# Question: When was Python 3.12 released?
#
# Prompt sent to Llama:
# Answer this question briefly: When was Python 3.12 released?
#
# ----------------------------------------------------------------------
# Llama's Response:
# Python 3.12 was released on April 26, 2022.
#
# ======================================================================
# 🟢 WITH RAG - Retrieve Context + LLM Query
# ======================================================================
# Question: When was Python 3.12 released?
#
# Retrieved Context from Knowledge Base:
#   1. Python 3.12 was released in October 2023 with improved error messages.
#
# Enhanced Prompt sent to Llama:
# Use the following context to answer the question:
#
# Context:
# Python 3.12 was released in October 2023 with improved error messages.
#
# Question: When was Python 3.12 released?
#
# Answer based on the context above:
#
# ----------------------------------------------------------------------
# Llama's Response:
# According to the context, Python 3.12 was released in October 2023.
#
# ======================================================================
# COMPARISON:
# ======================================================================
# Without RAG: Python 3.12 was released on April 26, 2022.
# With RAG: According to the context, Python 3.12 was released in October 2023.
# Result: More accurate, specific, and grounded responses!
#
# ======================================================================
# 🔴 WITHOUT RAG - Direct LLM Query
# ======================================================================
# Question: What does RAG stand for?
#
# Prompt sent to Llama:
# Answer this question briefly: What does RAG stand for?
#
# ----------------------------------------------------------------------
# Llama's Response:
# I don't have enough information to determine what "RAG" stands for. Can you provide more context or clarify which "RAG" you are referring to?
#
# ======================================================================
# 🟢 WITH RAG - Retrieve Context + LLM Query
# ======================================================================
# Question: What does RAG stand for?
#
# Retrieved Context from Knowledge Base:
#   1. RAG stands for Retrieval-Augmented Generation, combining search with LLMs.
#
# Enhanced Prompt sent to Llama:
# Use the following context to answer the question:
#
# Context:
# RAG stands for Retrieval-Augmented Generation, combining search with LLMs.
#
# Question: What does RAG stand for?
#
# Answer based on the context above:
#
# ----------------------------------------------------------------------
# Llama's Response:
# RAG stands for Retrieval-Augmented Generation.
#
# ======================================================================
# COMPARISON:
# ======================================================================
# Without RAG: I don't have enough information to determine what "RAG" stands for. Can you provide more context or clarify which "RAG" you are referring to?
# With RAG: RAG stands for Retrieval-Augmented Generation.
# Result: More accurate, specific, and grounded responses!
#
#
# ======================================================================
# DEMO COMPLETE!
# ======================================================================
#
# Key Takeaway:
# - WITHOUT RAG: Generic answers from training data
# - WITH RAG: Specific answers using your documents/data
#
# Use RAG when you need LLM to access:
#   • Your private documents
#   • Up-to-date information
#   • Domain-specific knowledge
#   • User-specific context
